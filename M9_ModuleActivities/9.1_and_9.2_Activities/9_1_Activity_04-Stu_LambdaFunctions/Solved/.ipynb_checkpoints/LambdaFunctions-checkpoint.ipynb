# %%
import pandas as pd

# %%
# Read in data set
movies_df = pd.read_csv(f'../Resources/movies_metadata.csv')
movies_df.head(2)
# Out:
#    adult    budget    id    imdb_id original_language original_title  \
# 0  False  30000000   862  tt0114709                en      Toy Story
# 1  False  65000000  8844  tt0113497                en        Jumanji
#
#                                             overview release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...     10/30/95
# 1  When siblings Judy and Peter discover an encha...     12/15/95
#
#        revenue  runtime    status                                    tagline  \
# 0  373554033.0     81.0  Released                                        NaN
# 1  262797249.0    104.0  Released  Roll the dice and unleash the excitement!
#
#        title  video  vote_average  vote_count
# 0  Toy Story  False           7.7      5415.0
# 1    Jumanji  False           6.9      2413.0

# %% [markdown]
# The following cell uses a function `more_than_15_words` to select the rows from `movies_df` that have titles with more than 15 words. In the next cell, do the same selection, but using a lambda function

# %%
def more_than_15_words(title):
    split_title = title.split() # split the title into a list of words
    number_of_words_in_title = len(split_title) # count the number of words in the title
    is_greater_than_15 = number_of_words_in_title > 15 # check if the number of words is greater than 15
    return is_greater_than_15 # return whether or not the title has more than 15 words

movies_df[movies_df['original_title'].apply(more_than_15_words)]
movies_df[movies_df['original_title'].apply(lambda x: len(x.split())>15)]
# Out:
#        adult   budget      id    imdb_id original_language  \
# 7241   False  5600000   10338  tt0059797                en
# 7268   False        0   65332  tt0070061                it
# 8420   False        0   22638  tt0036910                en
# 9227   False        0   22616  tt0230575                en
# 14093  False        0   36108  tt0973844                en
# 36823  False        0  270936  tt1023446                en
# 38508  False        0  132144  tt0072685                es
# 38511  False        0  132148  tt0074187                es
# 38512  False        0  132150  tt0078831                es
# 44212  False        0   85854  tt0052156                en
#
#                                           original_title  \
# 7241   Those Magnificent Men in Their Flying Machines...
# 7268   Film d'amore e d'anarchia, ovvero 'stamattina ...
# 8420   The Chronicle History of King Henry the Fifth ...
# 9227   Night of the Day of the Dawn of the Son of the...
# 14093  Chacun son cinema ou Ce petit coup au coeur qu...
# 36823  Ellen ten Damme: As I Was Wondering Where This...
# 38508  La batalla de Chile: La lucha de un pueblo sin...
# 38511  La batalla de Chile: La lucha de un pueblo sin...
# 38512  La batalla de Chile: La lucha de un pueblo sin...
# 44212  The Saga of the Viking Women and Their Voyage ...
#
#                                                 overview release_date  \
# 7241   Star studded comedy about a early 20th century...       6/3/65
# 7268   Set in Fascist Italy before the outbreak of Wo...      2/23/73
# 8420   Olivier mustered out of the navy to film this ...     11/24/44
# 9227   The makers of this parody of "Night of the Liv...       1/1/91
# 14093  A collective film of 33 shorts directed by dif...      5/19/07
# 36823  Documentary about Dutch artist Ellen ten Damme...      4/19/07
# 38508  Documents the rise of the right-wing movement ...      3/18/75
# 38511  Chronicles the events immediately surrounding ...      3/13/76
# 38512  Guzmán’s final instalment shifts from covering...      3/15/79
# 44212  A group of lonely Viking women build a ship an...      12/1/57
#
#           revenue  runtime    status  \
# 7241   29950000.0    138.0  Released
# 7268          0.0    120.0  Released
# 8420          0.0    137.0  Released
# 9227          0.0     96.0  Released
# 14093         0.0    100.0  Released
# 36823         0.0     66.0  Released
# 38508         0.0     97.0  Released
# 38511         0.0     88.0  Released
# 38512         0.0     78.0  Released
# 44212         0.0     66.0  Released
#
#                                                  tagline  \
# 7241   or How I Flew from London to Paris in 25 hours...
# 7268                                                 NaN
# 8420                                                 NaN
# 9227                                                 NaN
# 14093                                                NaN
# 36823                                                NaN
# 38508                                                NaN
# 38511                                                NaN
# 38512                                                NaN
# 44212  Fabulous! Spectacular! Terrifying! The raw cou...
#
#                                                    title  video  vote_average  \
# 7241   Those Magnificent Men in Their Flying Machines...  False           6.4
# 7268                                    Love and Anarchy  False           7.0
# 8420                                             Henry V  False           7.0
# 9227   Night of the Day of the Dawn of the Son of the...  False           5.3
# 14093                             To Each His Own Cinema  False           7.2
# 36823  Ellen ten Damme: As I Was Wondering Where This...  False           0.0
# 38508                       The Battle of Chile - Part I  False           6.3
# 38511                      The Battle of Chile - Part II  False           6.8
# 38512                     The Battle of Chile - Part III  False           6.0
# 44212  The Saga of the Viking Women and Their Voyage ...  False           2.0
#
#        vote_count
# 7241         40.0
# 7268          8.0
# 8420         25.0
# 9227          4.0
# 14093        26.0
# 36823         0.0
# 38508         4.0
# 38511         4.0
# 38512         3.0
# 44212         3.0

# %%
# Find all the movies that have more than 15 words in their title using a lambda function.
movies_df[movies_df['original_title'].map(lambda x: len(x.split())>15)]
# Out:
#        adult   budget      id    imdb_id original_language  \
# 7241   False  5600000   10338  tt0059797                en
# 7268   False        0   65332  tt0070061                it
# 8420   False        0   22638  tt0036910                en
# 9227   False        0   22616  tt0230575                en
# 14093  False        0   36108  tt0973844                en
# 36823  False        0  270936  tt1023446                en
# 38508  False        0  132144  tt0072685                es
# 38511  False        0  132148  tt0074187                es
# 38512  False        0  132150  tt0078831                es
# 44212  False        0   85854  tt0052156                en
#
#                                           original_title  \
# 7241   Those Magnificent Men in Their Flying Machines...
# 7268   Film d'amore e d'anarchia, ovvero 'stamattina ...
# 8420   The Chronicle History of King Henry the Fifth ...
# 9227   Night of the Day of the Dawn of the Son of the...
# 14093  Chacun son cinema ou Ce petit coup au coeur qu...
# 36823  Ellen ten Damme: As I Was Wondering Where This...
# 38508  La batalla de Chile: La lucha de un pueblo sin...
# 38511  La batalla de Chile: La lucha de un pueblo sin...
# 38512  La batalla de Chile: La lucha de un pueblo sin...
# 44212  The Saga of the Viking Women and Their Voyage ...
#
#                                                 overview release_date  \
# 7241   Star studded comedy about a early 20th century...       6/3/65
# 7268   Set in Fascist Italy before the outbreak of Wo...      2/23/73
# 8420   Olivier mustered out of the navy to film this ...     11/24/44
# 9227   The makers of this parody of "Night of the Liv...       1/1/91
# 14093  A collective film of 33 shorts directed by dif...      5/19/07
# 36823  Documentary about Dutch artist Ellen ten Damme...      4/19/07
# 38508  Documents the rise of the right-wing movement ...      3/18/75
# 38511  Chronicles the events immediately surrounding ...      3/13/76
# 38512  Guzmán’s final instalment shifts from covering...      3/15/79
# 44212  A group of lonely Viking women build a ship an...      12/1/57
#
#           revenue  runtime    status  \
# 7241   29950000.0    138.0  Released
# 7268          0.0    120.0  Released
# 8420          0.0    137.0  Released
# 9227          0.0     96.0  Released
# 14093         0.0    100.0  Released
# 36823         0.0     66.0  Released
# 38508         0.0     97.0  Released
# 38511         0.0     88.0  Released
# 38512         0.0     78.0  Released
# 44212         0.0     66.0  Released
#
#                                                  tagline  \
# 7241   or How I Flew from London to Paris in 25 hours...
# 7268                                                 NaN
# 8420                                                 NaN
# 9227                                                 NaN
# 14093                                                NaN
# 36823                                                NaN
# 38508                                                NaN
# 38511                                                NaN
# 38512                                                NaN
# 44212  Fabulous! Spectacular! Terrifying! The raw cou...
#
#                                                    title  video  vote_average  \
# 7241   Those Magnificent Men in Their Flying Machines...  False           6.4
# 7268                                    Love and Anarchy  False           7.0
# 8420                                             Henry V  False           7.0
# 9227   Night of the Day of the Dawn of the Son of the...  False           5.3
# 14093                             To Each His Own Cinema  False           7.2
# 36823  Ellen ten Damme: As I Was Wondering Where This...  False           0.0
# 38508                       The Battle of Chile - Part I  False           6.3
# 38511                      The Battle of Chile - Part II  False           6.8
# 38512                     The Battle of Chile - Part III  False           6.0
# 44212  The Saga of the Viking Women and Their Voyage ...  False           2.0
#
#        vote_count
# 7241         40.0
# 7268          8.0
# 8420         25.0
# 9227          4.0
# 14093        26.0
# 36823         0.0
# 38508         4.0
# 38511         4.0
# 38512         3.0
# 44212         3.0

# %%
def hundredfold_return(row):
    revenue = row['revenue']
    budget = row['budget']
    budget_over_1000 = budget > 1000
    revenue_over_100x = revenue > 100 * budget
    return revenue_over_100x and budget_over_1000
    
movies_df[movies_df.apply(hundredfold_return, axis=1)].head(1)
# Out:
#      adult  budget    id    imdb_id original_language original_title  \
# 219  False   27000  2292  tt0109445                en         Clerks
#
#                                               overview release_date  \
# 219  Convenience and video store clerks Dante and R...      9/13/94
#
#        revenue  runtime    status  \
# 219  3151130.0     92.0  Released
#
#                                                tagline   title  video  \
# 219  Just because they serve you doesn't mean they ...  Clerks  False
#
#      vote_average  vote_count
# 219           7.4       769.0

# %%
# Find all movies with budgets over 1000 that pulled in revenue over 100x their budget using a lambda function
movies_df[movies_df.apply(lambda row: row['revenue'] > 100 * row['budget'] and row['budget'] > 1000, axis=1)].head(1)
# Out:
#      adult  budget    id    imdb_id original_language original_title  \
# 219  False   27000  2292  tt0109445                en         Clerks
#
#                                               overview release_date  \
# 219  Convenience and video store clerks Dante and R...      9/13/94
#
#        revenue  runtime    status  \
# 219  3151130.0     92.0  Released
#
#                                                tagline   title  video  \
# 219  Just because they serve you doesn't mean they ...  Clerks  False
#
#      vote_average  vote_count
# 219           7.4       769.0

# %%
# load in list of English words
words_file = '../Resources/words.txt'

words_df = pd.read_csv(words_file, sep='\n', header=None)
words_df.columns = ['text']
words_df.head()
# Out:
#   text
# 0  the
# 1   of
# 2  and
# 3   to
# 4    a

# %%
words_df['text'].map(contains_x)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9878    False
# 9879    False
# 9880    False
# 9881    False
# 9882    False
# Name: text, Length: 9883, dtype: bool

# %%
def contains_x(word):
    split_word = list(word)
    word_contains_x = 'x' in split_word
    return word_contains_x

words_df[words_df['text'].map(contains_x)]
# Out:
#               text
# 97               x
# 120           next
# 274          index
# 347           text
# 449            box
# ...            ...
# 9748       expects
# 9759  examinations
# 9791       halifax
# 9808      examines
# 9872      lightbox
#
# [246 rows x 1 columns]

# %%
# Find all words containing the letter 'x' using a lambda function
words_df[words_df['text'].map(lambda word: 'x' in list(word))]
# Out:
#               text
# 97               x
# 120           next
# 274          index
# 347           text
# 449            box
# ...            ...
# 9748       expects
# 9759  examinations
# 9791       halifax
# 9808      examines
# 9872      lightbox
#
# [246 rows x 1 columns]
